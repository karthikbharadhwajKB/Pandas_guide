# %% [markdown]
# ## Pandas

# %% [markdown]
# ### Pandas DataFrame

# %% [markdown]
# 1 Pandas is a high-level data manipulation tool
#
# 2 it is built on the Numpy package and its key data structures called as DataFrame
#
# 3 DataFrame allows you to store and manipulate tabular data in row of observations and columns of variables

# %%
#DataFrame 

dict ={"country":['brazil','russia','india','italy','germany'],
      "capital":['brasilia','moscow','new delhi','rome','berlin'],
      'area':[8.66,89.33,67.66,97.33,89.78],
      'pop':[15,16,17,18,19]}

# %%
dict
# Out:
# {'country': ['brazil', 'russia', 'india', 'italy', 'germany'],
#  'capital': ['brasilia', 'moscow', 'new delhi', 'rome', 'berlin'],
#  'area': [8.66, 89.33, 67.66, 97.33, 89.78],
#  'pop': [15, 16, 17, 18, 19]}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(dict)

# %%
df1
# Out:
#    country    capital   area  pop
# 0   brazil   brasilia   8.66   15
# 1   russia     moscow  89.33   16
# 2    india  new delhi  67.66   17
# 3    italy       rome  97.33   18
# 4  germany     berlin  89.78   19

# %%
print(df1)
# Out:
#    country    capital   area  pop
# 0   brazil   brasilia   8.66   15
# 1   russia     moscow  89.33   16
# 2    india  new delhi  67.66   17
# 3    italy       rome  97.33   18
# 4  germany     berlin  89.78   19

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
cc = ['BR',"RU",'IN','IT','GE']

# %%
cc
# Out:
# ['BR', 'RU', 'IN', 'IT', 'GE']

# %%
df1.index = cc

# %%
df1
# Out:
#     country    capital   area  pop
# BR   brazil   brasilia   8.66   15
# RU   russia     moscow  89.33   16
# IN    india  new delhi  67.66   17
# IT    italy       rome  97.33   18
# GE  germany     berlin  89.78   19

# %%
df1.index
# Out:
# Index(['BR', 'RU', 'IN', 'IT', 'GE'], dtype='object')

# %% [markdown]
# ## Load Data from a file

# %%
data = r"C:\Users\Karthik Bharadhwaj\Python Datascience\Pandas\car_data.csv"

# %%
car_df = pd.read_csv(data)

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# 5             6         audi       gas        std          two        sedan
# 6             7         audi       gas        std         four        sedan
# 7             8         audi       gas        std         four        wagon
# 8             9         audi       gas      turbo         four        sedan
# 9            10         audi       gas      turbo          two    hatchback
# 10           11          bmw       gas        std          two        sedan
# ...

# %%
car_df.shape
# Out:
# (205, 23)

# %%
# head and tail 

car_df.head(10)
# Out:
#    Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0           1  alfa-romero       gas        std          two  convertible
# 1           2  alfa-romero       gas        std          two  convertible
# 2           3  alfa-romero       gas        std          two    hatchback
# 3           4         audi       gas        std         four        sedan
# 4           5         audi       gas        std         four        sedan
# 5           6         audi       gas        std          two        sedan
# 6           7         audi       gas        std         four        sedan
# 7           8         audi       gas        std         four        wagon
# 8           9         audi       gas      turbo         four        sedan
# 9          10         audi       gas      turbo          two    hatchback
#
#   drive_wheels engine_location  wheel_base  length  ...    engine_type  \
# 0          rwd           front        88.6   168.8  ...           dohc
# ...

# %%
#Tail 

car_df.tail()
# Out:
#      Unnamed: 0   make fuel_type aspiration num_of_doors body_style  \
# 200         201  volvo       gas        std         four      sedan
# 201         202  volvo       gas      turbo         four      sedan
# 202         203  volvo       gas        std         four      sedan
# 203         204  volvo    diesel      turbo         four      sedan
# 204         205  volvo       gas      turbo         four      sedan
#
#     drive_wheels engine_location  wheel_base  length  ...    engine_type  \
# 200          rwd           front       109.1   188.8  ...            ohc
# 201          rwd           front       109.1   188.8  ...            ohc
# 202          rwd           front       109.1   188.8  ...           ohcv
# 203          rwd           front       109.1   188.8  ...            ohc
# 204          rwd           front       109.1   188.8  ...            ohc
#
#      num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# ...

# %%
car_df.tail(50)
# Out:
#      Unnamed: 0        make fuel_type aspiration num_of_doors   body_style  \
# 155         156      toyota       gas        std         four        wagon
# 156         157      toyota       gas        std         four        sedan
# 157         158      toyota       gas        std         four    hatchback
# 158         159      toyota    diesel        std         four        sedan
# 159         160      toyota    diesel        std         four    hatchback
# 160         161      toyota       gas        std         four        sedan
# 161         162      toyota       gas        std         four    hatchback
# 162         163      toyota       gas        std         four        sedan
# 163         164      toyota       gas        std          two        sedan
# 164         165      toyota       gas        std          two    hatchback
# 165         166      toyota       gas        std          two        sedan
# ...

# %%
#info()-- information about dataframe 
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 23 columns):
# Unnamed: 0           205 non-null int64
# make                 205 non-null object
# fuel_type            205 non-null object
# aspiration           205 non-null object
# num_of_doors         205 non-null object
# body_style           205 non-null object
# drive_wheels         205 non-null object
# engine_location      205 non-null object
# wheel_base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb_weight          205 non-null int64
# engine_type          205 non-null object
# num_of_cylinders     205 non-null object
# engine_size          205 non-null int64
# fuel_system          205 non-null object
# compression_ratio    205 non-null float64
# horsepower           205 non-null object
# peak_rpm             205 non-null object
# ...

# %%
print(car_df.columns)
# Out:
# Index(['Unnamed: 0', 'make', 'fuel_type', 'aspiration', 'num_of_doors',
#        'body_style', 'drive_wheels', 'engine_location', 'wheel_base', 'length',
#        'width', 'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
#statistical data 
car_df.describe()
# Out:
#        Unnamed: 0  wheel_base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000   98.756585  174.049268   65.907805   53.724878
# std     59.322565    6.021776   12.337289    2.145204    2.443522
# min      1.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb_weight  engine_size  compression_ratio    city_mpg  highway_mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
# to check datatypes of columns 

car_df.dtypes
# Out:
# Unnamed: 0             int64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# ## Accessing the Dataframe content -- Indexing and Selecting Data

# %% [markdown]
# 1 DataFrame[ ] : [ ] index operator m
#
# 2 DataFrame.loc[ ] : used for labels
#
# 3 DataFrame.iloc[ ] :  used for positions or integers based

# %% [markdown]
# ## Using DataFrame[ ]

# %%
# accessing 
car_df['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9             audi
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 16             bmw
# 17             bmw
# 18       chevrolet
# 19       chevrolet
# 20       chevrolet
# 21           dodge
# 22           dodge
# 23           dodge
# 24           dodge
# 25           dodge
# 26           dodge
# 27           dodge
# 28           dodge
# 29           dodge
#           ...
# 175         toyota
# 176         toyota
# 177         toyota
# 178         toyota
# 179         toyota
# 180         toyota
# 181         toyota
# 182     volkswagen
# 183     volkswagen
# 184     volkswagen
# 185     volkswagen
# 186     volkswagen
# 187     volkswagen
# 188     volkswagen
# 189     volkswagen
# 190     volkswagen
# ...

# %%
v = car_df['fuel_type'].head(10)

# %%
u = car_df[['make','fuel_type']].head()

# %%
type(v)
# Out:
# pandas.core.series.Series

# %%
type(u)
# Out:
# pandas.core.frame.DataFrame

# %%
v
# Out:
# 0    gas
# 1    gas
# 2    gas
# 3    gas
# 4    gas
# 5    gas
# 6    gas
# 7    gas
# 8    gas
# 9    gas
# Name: fuel_type, dtype: object

# %%
u
# Out:
#           make fuel_type
# 0  alfa-romero       gas
# 1  alfa-romero       gas
# 2  alfa-romero       gas
# 3         audi       gas
# 4         audi       gas

# %%
car_df.make
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9             audi
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 16             bmw
# 17             bmw
# 18       chevrolet
# 19       chevrolet
# 20       chevrolet
# 21           dodge
# 22           dodge
# 23           dodge
# 24           dodge
# 25           dodge
# 26           dodge
# 27           dodge
# 28           dodge
# 29           dodge
#           ...
# 175         toyota
# 176         toyota
# 177         toyota
# 178         toyota
# 179         toyota
# 180         toyota
# 181         toyota
# 182     volkswagen
# 183     volkswagen
# 184     volkswagen
# 185     volkswagen
# 186     volkswagen
# 187     volkswagen
# 188     volkswagen
# 189     volkswagen
# 190     volkswagen
# ...

# %%
print(car_df.make.unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']

# %% [markdown]
# ## Using DataFrame.loc[]

# %%
df1
# Out:
#     country    capital   area  pop
# BR   brazil   brasilia   8.66   15
# RU   russia     moscow  89.33   16
# IN    india  new delhi  67.66   17
# IT    italy       rome  97.33   18
# GE  germany     berlin  89.78   19

# %%
v = df1.loc['IN']

# %%
type(v)
# Out:
# pandas.core.series.Series

# %%
df1.loc[['IN','IT']]
# Out:
#    country    capital   area  pop
# IN   india  new delhi  67.66   17
# IT   italy       rome  97.33   18

# %%
#[rows ,columns ]
df1.loc[['IN','IT'],['area','pop']]
# Out:
#      area  pop
# IN  67.66   17
# IT  97.33   18

# %%
# without selecting rows 
df1.loc[:,['area','pop']]
# Out:
#      area  pop
# BR   8.66   15
# RU  89.33   16
# IN  67.66   17
# IT  97.33   18
# GE  89.78   19

# %%
# without selecting columns 
df1.loc[['IN','IT'],:]
# Out:
#    country    capital   area  pop
# IN   india  new delhi  67.66   17
# IT   italy       rome  97.33   18

# %% [markdown]
# ## Using DataFrame iloc[ ]

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# 5             6         audi       gas        std          two        sedan
# 6             7         audi       gas        std         four        sedan
# 7             8         audi       gas        std         four        wagon
# 8             9         audi       gas      turbo         four        sedan
# 9            10         audi       gas      turbo          two    hatchback
# 10           11          bmw       gas        std          two        sedan
# ...

# %%
car_df.iloc[2]
# Out:
# Unnamed: 0                     3
# make                 alfa-romero
# fuel_type                    gas
# aspiration                   std
# num_of_doors                 two
# body_style             hatchback
# drive_wheels                 rwd
# engine_location            front
# wheel_base                  94.5
# length                     171.2
# width                       65.5
# height                      52.4
# curb_weight                 2823
# engine_type                 ohcv
# num_of_cylinders             six
# engine_size                  152
# fuel_system                 mpfi
# compression_ratio              9
# horsepower                   154
# peak_rpm                    5000
# city_mpg                      19
# highway_mpg                   26
# price                      16500
# Name: 2, dtype: object

# %%
car_df.iloc[[1,3,5,7]]
# Out:
#    Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 1           2  alfa-romero       gas        std          two  convertible
# 3           4         audi       gas        std         four        sedan
# 5           6         audi       gas        std          two        sedan
# 7           8         audi       gas        std         four        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...    engine_type  \
# 1          rwd           front        88.6   168.8  ...           dohc
# 3          fwd           front        99.8   176.6  ...            ohc
# 5          fwd           front        99.8   177.3  ...            ohc
# 7          fwd           front       105.8   192.7  ...            ohc
#
#    num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# 1              four          130        mpfi               9.0         111
# 3              four          109        mpfi              10.0         102
# ...

# %%
car_df.iloc[1:8]
# Out:
#    Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 1           2  alfa-romero       gas        std          two  convertible
# 2           3  alfa-romero       gas        std          two    hatchback
# 3           4         audi       gas        std         four        sedan
# 4           5         audi       gas        std         four        sedan
# 5           6         audi       gas        std          two        sedan
# 6           7         audi       gas        std         four        sedan
# 7           8         audi       gas        std         four        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...    engine_type  \
# 1          rwd           front        88.6   168.8  ...           dohc
# 2          rwd           front        94.5   171.2  ...           ohcv
# 3          fwd           front        99.8   176.6  ...            ohc
# 4          4wd           front        99.4   176.6  ...            ohc
# ...

# %%
# [[rows],[columns]]
car_df.iloc[[4,6],[2,9]]
# Out:
#   fuel_type  length
# 4       gas   176.6
# 6       gas   192.7

# %%
car_df.iloc[:,[2,6,9,10]]
# Out:
#     fuel_type drive_wheels  length  width
# 0         gas          rwd   168.8   64.1
# 1         gas          rwd   168.8   64.1
# 2         gas          rwd   171.2   65.5
# 3         gas          fwd   176.6   66.2
# 4         gas          4wd   176.6   66.4
# 5         gas          fwd   177.3   66.3
# 6         gas          fwd   192.7   71.4
# 7         gas          fwd   192.7   71.4
# 8         gas          fwd   192.7   71.4
# 9         gas          4wd   178.2   67.9
# 10        gas          rwd   176.8   64.8
# 11        gas          rwd   176.8   64.8
# 12        gas          rwd   176.8   64.8
# 13        gas          rwd   176.8   64.8
# 14        gas          rwd   189.0   66.9
# 15        gas          rwd   189.0   66.9
# 16        gas          rwd   193.8   67.9
# 17        gas          rwd   197.0   70.9
# 18        gas          fwd   141.1   60.3
# 19        gas          fwd   155.9   63.6
# 20        gas          fwd   158.8   63.6
# ...

# %%
car_df.iloc[10:20,1:9]
# Out:
#          make fuel_type aspiration num_of_doors body_style drive_wheels  \
# 10        bmw       gas        std          two      sedan          rwd
# 11        bmw       gas        std         four      sedan          rwd
# 12        bmw       gas        std          two      sedan          rwd
# 13        bmw       gas        std         four      sedan          rwd
# 14        bmw       gas        std         four      sedan          rwd
# 15        bmw       gas        std         four      sedan          rwd
# 16        bmw       gas        std          two      sedan          rwd
# 17        bmw       gas        std         four      sedan          rwd
# 18  chevrolet       gas        std          two  hatchback          fwd
# 19  chevrolet       gas        std          two  hatchback          fwd
#
#    engine_location  wheel_base
# 10           front       101.2
# 11           front       101.2
# 12           front       101.2
# 13           front       101.2
# ...

# %%
#conditional statement 

car_df[car_df.make == 'audi']
# Out:
#    Unnamed: 0  make fuel_type aspiration num_of_doors body_style drive_wheels  \
# 3           4  audi       gas        std         four      sedan          fwd
# 4           5  audi       gas        std         four      sedan          4wd
# 5           6  audi       gas        std          two      sedan          fwd
# 6           7  audi       gas        std         four      sedan          fwd
# 7           8  audi       gas        std         four      wagon          fwd
# 8           9  audi       gas      turbo         four      sedan          fwd
# 9          10  audi       gas      turbo          two  hatchback          4wd
#
#   engine_location  wheel_base  length  ...    engine_type  num_of_cylinders  \
# 3           front        99.8   176.6  ...            ohc              four
# 4           front        99.4   176.6  ...            ohc              five
# 5           front        99.8   177.3  ...            ohc              five
# ...

# %%
car_df.make == 'audi'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: make, Length: 205, dtype: bool

# %%
car_df[car_df.wheel_base > 115]
# Out:
#     Unnamed: 0           make fuel_type aspiration num_of_doors body_style  \
# 70          71  mercedes-benz    diesel      turbo         four      sedan
# 71          72  mercedes-benz       gas        std         four      sedan
# 73          74  mercedes-benz       gas        std         four      sedan
#
#    drive_wheels engine_location  wheel_base  length  ...    engine_type  \
# 70          rwd           front       115.6   202.6  ...            ohc
# 71          rwd           front       115.6   202.6  ...           ohcv
# 73          rwd           front       120.9   208.1  ...           ohcv
#
#     num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# 70              five          183         idi              21.5         123
# 71             eight          234        mpfi               8.3         155
# 73             eight          308        mpfi               8.0         184
#
#    peak_rpm  city_mpg highway_mpg  price
# ...

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# 5             6         audi       gas        std          two        sedan
# 6             7         audi       gas        std         four        sedan
# 7             8         audi       gas        std         four        wagon
# 8             9         audi       gas      turbo         four        sedan
# 9            10         audi       gas      turbo          two    hatchback
# 10           11          bmw       gas        std          two        sedan
# ...

# %%
car_df[(car_df.aspiration == 'turbo') & (car_df.num_of_cylinders == 'five')].iloc[:,[2,5,7,9]]
# Out:
#    fuel_type body_style engine_location  length
# 8        gas      sedan           front   192.7
# 9        gas  hatchback           front   178.2
# 67    diesel      sedan           front   190.9
# 68    diesel      wagon           front   190.9
# 69    diesel    hardtop           front   187.5
# 70    diesel      sedan           front   202.6

# %%
car_df[(car_df.make == 'bmw')  | (car_df.wheel_base > 110)]
# Out:
#      Unnamed: 0           make fuel_type aspiration num_of_doors body_style  \
# 10           11            bmw       gas        std          two      sedan
# 11           12            bmw       gas        std         four      sedan
# 12           13            bmw       gas        std          two      sedan
# 13           14            bmw       gas        std         four      sedan
# 14           15            bmw       gas        std         four      sedan
# 15           16            bmw       gas        std         four      sedan
# 16           17            bmw       gas        std          two      sedan
# 17           18            bmw       gas        std         four      sedan
# 47           48         jaguar       gas        std         four      sedan
# 48           49         jaguar       gas        std         four      sedan
# 70           71  mercedes-benz    diesel      turbo         four      sedan
# ...

# %%
print(car_df.columns)
# Out:
# Index(['Unnamed: 0', 'make', 'fuel_type', 'aspiration', 'num_of_doors',
#        'body_style', 'drive_wheels', 'engine_location', 'wheel_base', 'length',
#        'width', 'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
# renaming column names 
car_df.rename(columns={'Unnamed: 0':'Serial_NO','make':'manufacturer'},inplace=True)

# %%
car_df
# Out:
#      Serial_NO manufacturer fuel_type aspiration num_of_doors   body_style  \
# 0            1  alfa-romero       gas        std          two  convertible
# 1            2  alfa-romero       gas        std          two  convertible
# 2            3  alfa-romero       gas        std          two    hatchback
# 3            4         audi       gas        std         four        sedan
# 4            5         audi       gas        std         four        sedan
# 5            6         audi       gas        std          two        sedan
# 6            7         audi       gas        std         four        sedan
# 7            8         audi       gas        std         four        wagon
# 8            9         audi       gas      turbo         four        sedan
# 9           10         audi       gas      turbo          two    hatchback
# 10          11          bmw       gas        std          two        sedan
# ...

# %%
#creating a copy
car_df_backup = car_df.copy()

# %%
car_df_backup
# Out:
#      Serial_NO manufacturer fuel_type aspiration num_of_doors   body_style  \
# 0            1  alfa-romero       gas        std          two  convertible
# 1            2  alfa-romero       gas        std          two  convertible
# 2            3  alfa-romero       gas        std          two    hatchback
# 3            4         audi       gas        std         four        sedan
# 4            5         audi       gas        std         four        sedan
# 5            6         audi       gas        std          two        sedan
# 6            7         audi       gas        std         four        sedan
# 7            8         audi       gas        std         four        wagon
# 8            9         audi       gas      turbo         four        sedan
# 9           10         audi       gas      turbo          two    hatchback
# 10          11          bmw       gas        std          two        sedan
# ...

# %%
df1
# Out:
#     country    capital   area  pop
# BR   brazil   brasilia   8.66   15
# RU   russia     moscow  89.33   16
# IN    india  new delhi  67.66   17
# IT    italy       rome  97.33   18
# GE  germany     berlin  89.78   19

# %%
# changing entire column names  
newCol = ['Country','Capital','Area','Pop']

# %%
df1.columns = newCol

# %%
df1
# Out:
#     Country    Capital   Area  Pop
# BR   brazil   brasilia   8.66   15
# RU   russia     moscow  89.33   16
# IN    india  new delhi  67.66   17
# IT    italy       rome  97.33   18
# GE  germany     berlin  89.78   19

# %% [markdown]
# ## Droping Columns

# %%
df1
# remove pop column
# Out:
#     Country    Capital   Area  Pop
# BR   brazil   brasilia   8.66   15
# RU   russia     moscow  89.33   16
# IN    india  new delhi  67.66   17
# IT    italy       rome  97.33   18
# GE  germany     berlin  89.78   19

# %%
df1.drop('Pop',axis = 1, inplace= True)

# %%
df1
# Out:
#     Country    Capital   Area
# BR   brazil   brasilia   8.66
# RU   russia     moscow  89.33
# IN    india  new delhi  67.66
# IT    italy       rome  97.33
# GE  germany     berlin  89.78

# %%
df1.drop('BR',axis = 0 ,inplace= True)  # axis =  0  it is default

# %%
df1
# Out:
#     Country    Capital   Area
# RU   russia     moscow  89.33
# IN    india  new delhi  67.66
# IT    italy       rome  97.33
# GE  germany     berlin  89.78

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# 5             6         audi       gas        std          two        sedan
# 6             7         audi       gas        std         four        sedan
# 7             8         audi       gas        std         four        wagon
# 8             9         audi       gas      turbo         four        sedan
# 9            10         audi       gas      turbo          two    hatchback
# 10           11          bmw       gas        std          two        sedan
# ...

# %%
d =car_df[['make','price']].sort_values(['make','price'])

# %%
d
# Out:
#             make  price
# 0    alfa-romero  13495
# 1    alfa-romero  16500
# 2    alfa-romero  16500
# 3           audi  13950
# 4           audi  17450
# 5           audi  15250
# 6           audi  17710
# 7           audi  18920
# 8           audi  23875
# 9           audi      ?
# 17           bmw  36880
# 16           bmw  41315
# 15           bmw  30760
# 14           bmw  24565
# 12           bmw  20970
# 11           bmw  16925
# 10           bmw  16430
# 13           bmw  21105
# 18     chevrolet   5151
# 19     chevrolet   6295
# 20     chevrolet   6575
# 27         dodge   8558
# 29         dodge  12964
# 28         dodge   8921
# 26         dodge   7609
# 23         dodge   7957
# 24         dodge   6229
# 22         dodge   6377
# 21         dodge   5572
# 25         dodge   6692
# ..           ...    ...
# 158       toyota   7898
# 159       toyota   7788
# 160       toyota   7738
# 161       toyota   8358
# 162       toyota   9258
# 163       toyota   8058
# ...

# %%
car_df[car_df.price.str.contains('\?')]
# Out:
#      Unnamed: 0     make fuel_type aspiration num_of_doors body_style  \
# 9            10     audi       gas      turbo          two  hatchback
# 44           45    isuzu       gas        std          two      sedan
# 45           46    isuzu       gas        std         four      sedan
# 129         130  porsche       gas        std          two  hatchback
#
#     drive_wheels engine_location  wheel_base  length  ...   engine_type  \
# 9            4wd           front        99.5   178.2  ...           ohc
# 44           fwd           front        94.5   155.9  ...           ohc
# 45           fwd           front        94.5   155.9  ...           ohc
# 129          rwd           front        98.4   175.7  ...         dohcv
#
#      num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# 9                five          131        mpfi               7.0         160
# 44               four           90        2bbl               9.6          70
# ...

# %%
car_df[car_df['price']=='?']
# Out:
#      Unnamed: 0     make fuel_type aspiration num_of_doors body_style  \
# 9            10     audi       gas      turbo          two  hatchback
# 44           45    isuzu       gas        std          two      sedan
# 45           46    isuzu       gas        std         four      sedan
# 129         130  porsche       gas        std          two  hatchback
#
#     drive_wheels engine_location  wheel_base  length  ...   engine_type  \
# 9            4wd           front        99.5   178.2  ...           ohc
# 44           fwd           front        94.5   155.9  ...           ohc
# 45           fwd           front        94.5   155.9  ...           ohc
# 129          rwd           front        98.4   175.7  ...         dohcv
#
#      num_of_cylinders  engine_size fuel_system compression_ratio  horsepower  \
# 9                five          131        mpfi               7.0         160
# 44               four           90        2bbl               9.6          70
# ...

# %%
car_df['price'] = car_df.price.str.replace('\?','100')

# %%
car_df['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
# 5      15250
# 6      17710
# 7      18920
# 8      23875
# 9        100
# 10     16430
# 11     16925
# 12     20970
# 13     21105
# 14     24565
# 15     30760
# 16     41315
# 17     36880
# 18      5151
# 19      6295
# 20      6575
# 21      5572
# 22      6377
# 23      7957
# 24      6229
# 25      6692
# 26      7609
# 27      8558
# 28      8921
# 29     12964
#        ...
# 175     9988
# 176    10898
# 177    11248
# 178    16558
# 179    15998
# 180    15690
# 181    15750
# 182     7775
# 183     7975
# 184     7995
# 185     8195
# 186     8495
# 187     9495
# 188     9995
# 189    11595
# 190     9980
# 191    13295
# 192    13845
# 193    12290
# 194    12940
# 195    13415
# 196    15985
# 197    16515
# 198    18420
# 199    18950
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
car_df.price= car_df.price.str.replace('\?','63000')

# %%
car_df['price']
# Out:
# 0      63000163000363000463000963000563000
# 1      63000163000663000563000063000063000
# 2      63000163000663000563000063000063000
# 3      63000163000363000963000563000063000
# 4      63000163000763000463000563000063000
# 5      63000163000563000263000563000063000
# 6      63000163000763000763000163000063000
# 7      63000163000863000963000263000063000
# 8      63000263000363000863000763000563000
# 9      63000663000363000063000063000063000
# 10     63000163000663000463000363000063000
# 11     63000163000663000963000263000563000
# 12     63000263000063000963000763000063000
# 13     63000263000163000163000063000563000
# 14     63000263000463000563000663000563000
# 15     63000363000063000763000663000063000
# 16     63000463000163000363000163000563000
# 17     63000363000663000863000863000063000
# 18           63000563000163000563000163000
# 19           63000663000263000963000563000
# 20           63000663000563000763000563000
# 21           63000563000563000763000263000
# ...

# %%
import numpy as np
car_df['price'] = car_df.price.astype(np.float64)

# %%
car_df['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
# 6      17710.0
# 7      18920.0
# 8      23875.0
# 9        100.0
# 10     16430.0
# 11     16925.0
# 12     20970.0
# 13     21105.0
# 14     24565.0
# 15     30760.0
# 16     41315.0
# 17     36880.0
# 18      5151.0
# 19      6295.0
# 20      6575.0
# 21      5572.0
# 22      6377.0
# 23      7957.0
# 24      6229.0
# 25      6692.0
# 26      7609.0
# 27      8558.0
# 28      8921.0
# 29     12964.0
#         ...
# 175     9988.0
# 176    10898.0
# 177    11248.0
# 178    16558.0
# 179    15998.0
# 180    15690.0
# 181    15750.0
# 182     7775.0
# 183     7975.0
# 184     7995.0
# 185     8195.0
# 186     8495.0
# 187     9495.0
# 188     9995.0
# 189    11595.0
# 190     9980.0
# 191    13295.0
# 192    13845.0
# 193    12290.0
# 194    12940.0
# 195    13415.0
# 196    15985.0
# 197    16515.0
# 198    18420.0
# 199    18950.0
# 200    16845.0
# 201    19045.0
# 202    21485.0
# ...
